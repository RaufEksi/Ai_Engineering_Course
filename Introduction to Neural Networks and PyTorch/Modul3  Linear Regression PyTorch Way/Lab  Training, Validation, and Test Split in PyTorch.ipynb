# %%
from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import optim

# %%
from torch.utils.data import Dataset, Dataloader

class Data(Dataset):
  def __init__(self, train=True):
    self.x = torch.arange(-3,3,0.)
